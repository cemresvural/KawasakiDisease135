# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\cemre\\Desktop\\Datasets\\genes_49.csv")
df.head(10)
# Out:
#   Unnamed: 0     PTAFR      PYGL  APOBEC3G      LY6E     SIRPA     ITGB3  \
# 0        KD1  0.440189 -0.130133 -0.566502  0.018539 -0.148853 -0.655902
# 1        KD2  0.055643  0.074221  0.523488 -0.359842  0.481421 -0.167625
# 2        KD3 -0.262518  1.026176 -0.610592 -1.733881  0.588404  0.000000
# 3        KD4  0.111459  0.460707 -0.523488  1.125364  0.074221 -0.726531
# 4        KD5  0.037085 -0.566502 -0.055643  0.460707  0.186456  1.237070
# 5        KD6  2.260761  2.260761  0.399693  0.037085  2.260761  0.679066
# 6        KD7 -0.775693 -0.907819  0.018539 -0.523488 -0.750885  0.702601
# 7        KD8  0.566502  0.907819 -0.655902 -1.321069  0.936176  2.260761
# 8        KD9  0.523488  0.481421 -0.965306 -1.237070  1.237070 -0.750885
# 9       KD10  2.068794  2.068794  0.679066 -0.186456  1.415589  1.321069
#
#       IGF1R     DGAT2    IL1RAP  ...       CR1   GTF2IP4      CD38     MAML3  \
# 0 -0.523488  0.148853 -0.359842  ... -0.481421  0.359842 -0.750885 -0.055643
# ...

# %%
df.shape
# Out:
# (135, 50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 50 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  135 non-null    object
#  1   PTAFR       135 non-null    float64
#  2   PYGL        135 non-null    float64
#  3   APOBEC3G    135 non-null    float64
#  4   LY6E        135 non-null    float64
#  5   SIRPA       135 non-null    float64
#  6   ITGB3       135 non-null    float64
#  7   IGF1R       135 non-null    float64
#  8   DGAT2       135 non-null    float64
#  9   IL1RAP      135 non-null    float64
#  10  MYADM       135 non-null    float64
#  11  TMCO3       135 non-null    float64
#  12  MPZL1       135 non-null    float64
#  13  RFLNB       135 non-null    float64
#  14  IFI44L      135 non-null    float64
#  15  PPBP        135 non-null    float64
#  16  MASTL       135 non-null    float64
#  17  PGAP1       135 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# PTAFR         0
# PYGL          0
# APOBEC3G      0
# LY6E          0
# SIRPA         0
# ITGB3         0
# IGF1R         0
# DGAT2         0
# IL1RAP        0
# MYADM         0
# TMCO3         0
# MPZL1         0
# RFLNB         0
# IFI44L        0
# PPBP          0
# MASTL         0
# PGAP1         0
# CUL1          0
# GNAQ          0
# IMPA2         0
# TAGLN2        0
# PI4K2B        0
# KLHL2         0
# SIGLEC10      0
# BCL6          0
# GIMAP6        0
# SORL1         0
# F13A1         0
# TBC1D14       0
# NLRP12        0
# GALM          0
# INPP5A        0
# ISG15         0
# NIBAN1        0
# OAS2          0
# ALOX5         0
# RTN3          0
# PRKAR2B       0
# MANSC1        0
# CR1           0
# GTF2IP4       0
# CD38          0
# MAML3         0
# CMTR1         0
# APOL3         0
# TSPAN2        0
# H2BC6         0
# H3C12         0
# H3C3          0
# dtype: int64

# %%
df=df.iloc[:,1:]
df.head()
# Out:
#       PTAFR      PYGL  APOBEC3G      LY6E     SIRPA     ITGB3     IGF1R  \
# 0  0.440189 -0.130133 -0.566502  0.018539 -0.148853 -0.655902 -0.523488
# 1  0.055643  0.074221  0.523488 -0.359842  0.481421 -0.167625  0.800987
# 2 -0.262518  1.026176 -0.610592 -1.733881  0.588404  0.000000  0.655902
# 3  0.111459  0.460707 -0.523488  1.125364  0.074221 -0.726531  0.205354
# 4  0.037085 -0.566502 -0.055643  0.460707  0.186456  1.237070  0.359842
#
#       DGAT2    IL1RAP     MYADM  ...       CR1   GTF2IP4      CD38     MAML3  \
# 0  0.148853 -0.359842  0.633085  ... -0.481421  0.359842 -0.750885 -0.055643
# 1  0.186456  0.224325  0.610592  ... -0.243377  0.000000  1.160996  0.523488
# 2 -0.111459 -0.055643 -0.419855  ...  1.125364  1.026176  0.074221  0.907819
# 3  0.853185  1.026176  0.243377  ...  1.237070 -0.419855 -0.775693  0.633085
# 4 -0.359842 -0.544869  0.037085  ... -0.523488 -0.074221  0.610592  0.853185
#
#       CMTR1     APOL3    TSPAN2     H2BC6     H3C12      H3C3
# ...

# %%
df.describe()
# Out:
#               PTAFR          PYGL      APOBEC3G          LY6E         SIRPA  \
# count  1.350000e+02  1.350000e+02  1.350000e+02  1.350000e+02  1.350000e+02
# mean  -2.878356e-16 -2.201942e-16 -1.796917e-16  1.716166e-07 -1.743975e-16
# std    9.925155e-01  9.925155e-01  9.925155e-01  9.925148e-01  9.925155e-01
# min   -2.612709e+00 -2.612709e+00 -2.612709e+00 -2.612709e+00 -2.612709e+00
# 25%   -6.674844e-01 -6.674844e-01 -6.674844e-01 -6.674844e-01 -6.674844e-01
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    6.674844e-01  6.674844e-01  6.674844e-01  6.674844e-01  6.674844e-01
# max    2.612709e+00  2.612709e+00  2.612709e+00  2.612709e+00  2.612709e+00
#
#               ITGB3         IGF1R         DGAT2        IL1RAP         MYADM  \
# count  1.350000e+02  1.350000e+02  1.350000e+02  1.350000e+02  1.350000e+02
# mean  -1.792805e-16 -2.458938e-16 -1.581040e-16 -1.576928e-16 -1.348715e-16
# ...

# %%
df.columns
# Out:
# Index(['PTAFR', 'PYGL', 'APOBEC3G', 'LY6E', 'SIRPA', 'ITGB3', 'IGF1R', 'DGAT2',
#        'IL1RAP', 'MYADM', 'TMCO3', 'MPZL1', 'RFLNB', 'IFI44L', 'PPBP', 'MASTL',
#        'PGAP1', 'CUL1', 'GNAQ', 'IMPA2', 'TAGLN2', 'PI4K2B', 'KLHL2',
#        'SIGLEC10', 'BCL6', 'GIMAP6', 'SORL1', 'F13A1', 'TBC1D14', 'NLRP12',
#        'GALM', 'INPP5A', 'ISG15', 'NIBAN1', 'OAS2', 'ALOX5', 'RTN3', 'PRKAR2B',
#        'MANSC1', 'CR1', 'GTF2IP4', 'CD38', 'MAML3', 'CMTR1', 'APOL3', 'TSPAN2',
#        'H2BC6', 'H3C12', 'H3C3'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(18, 18))

sns.heatmap(df.corr(),
            cmap='turbo',
            square=True,
            linewidths=0.1,
            vmax=1,
            vmin=-1,
            center=0)

plt.show()

# %%
df1=pd.DataFrame(df)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df1)

# %%
scores = []
for k in range(2,15):
    km = KMeans(n_clusters=k,random_state=123)
    km = km.fit(df1)
    scores.append(km.inertia_)
dfk = pd.DataFrame({'Cluster':range(2,15), 'Score':scores})
plt.figure(figsize=(8,5))
plt.plot(dfk['Cluster'], dfk['Score'], marker='o')
plt.xlabel('Küme Sayısı')
plt.ylabel('Inertia')
plt.show()

# %%
from sklearn import metrics

# %%
for i in range(4,10):
    kmeans_labels=KMeans(n_clusters=i,random_state=123).fit_predict(df1)
    print("Silhouette skoru {} için  clusters k-means : {} ".format(i,metrics.silhouette_score(df1,kmeans_labels, metric='euclidean')))
# Out:
# Silhouette skoru 4 için  clusters k-means : 0.26309827545653974
# Silhouette skoru 5 için  clusters k-means : 0.23154353873077654
# Silhouette skoru 6 için  clusters k-means : 0.23263039286572504
# Silhouette skoru 7 için  clusters k-means : 0.1952796877293189
# Silhouette skoru 8 için  clusters k-means : 0.19720403721851598
# Silhouette skoru 9 için  clusters k-means : 0.18896086155015665

# %%
for i in [4,5,6,7,8]:
    kmeans_labels=KMeans(n_clusters=i,random_state=123).fit_predict(df1)
    print('Davies Bouldin Score:'+str(metrics.davies_bouldin_score(df1,kmeans_labels).round(3)))
# Out:
# Davies Bouldin Score:1.169
# Davies Bouldin Score:1.355
# Davies Bouldin Score:1.378
# Davies Bouldin Score:1.559
# Davies Bouldin Score:1.526

# %%
kmeans_labels=KMeans(n_clusters=4,random_state=123).fit_predict(df1)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3).fit_transform(df1)
fig = plt.figure(figsize=(20, 9), dpi=80, facecolor='w', edgecolor='k')
ax = plt.axes(projection="3d")
ax.scatter3D(pca.T[0],pca.T[1],pca.T[2],c=kmeans_labels,cmap='Spectral')

xLabel = ax.set_xlabel('X')
yLabel = ax.set_ylabel('Y')
zLabel = ax.set_zlabel('Z')

# %%
from sklearn.cluster import MiniBatchKMeans

# %%
for i in range(4,10):
    minikm_labels = MiniBatchKMeans(n_clusters=i,init='random',batch_size=1000).fit_predict(df1)
    print("clusters  {} için  MiniBatch k-means Silhouette skoru : {}".format(i,metrics.silhouette_score(df1, minikm_labels,metric='euclidean')))
# Out:
# clusters  4 için  MiniBatch k-means Silhouette skoru : 0.22918872353135358
# clusters  5 için  MiniBatch k-means Silhouette skoru : 0.24148475829305305
# clusters  6 için  MiniBatch k-means Silhouette skoru : 0.20263496290376395
# clusters  7 için  MiniBatch k-means Silhouette skoru : 0.16105197930349796
# clusters  8 için  MiniBatch k-means Silhouette skoru : 0.15646375854271533
# clusters  9 için  MiniBatch k-means Silhouette skoru : 0.16858839866818073

# %%
for i in [4,6,7,8]:
    minikm_labels = MiniBatchKMeans(n_clusters=i,init='random',batch_size=1000).fit_predict(df1)
    print('Davies Bouldin Score:'+str(metrics.davies_bouldin_score(df1,minikm_labels).round(3)))
# Out:
# Davies Bouldin Score:1.657
# Davies Bouldin Score:1.506
# Davies Bouldin Score:1.602
# Davies Bouldin Score:1.687

# %%
minikm_labels = MiniBatchKMeans(n_clusters=4,init='random',batch_size=1000).fit_predict(df1)

# %%
fig = plt.figure(figsize=(12, 7), dpi=80, facecolor='w', edgecolor='k')
ax = plt.axes(projection="3d")
ax.scatter3D(pca.T[0],pca.T[1],pca.T[2],c=minikm_labels,cmap='Spectral')

xLabel = ax.set_xlabel('X')
yLabel = ax.set_ylabel('Y')
zLabel = ax.set_zlabel('Z')

# %%
import scipy.cluster.hierarchy as shc

# %%
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(df1, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
hcluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')  
hcp=hcluster.fit_predict(df1)
print('Hiyerarşik Kümeleme için Siluet Puanı:'+str(metrics.silhouette_score(df1,hcp,metric='euclidean')))
print('Davies Bouldin Puanı:'+str(metrics.davies_bouldin_score(df1,hcp)))
# Out:
# Hiyerarşik Kümeleme için Siluet Puanı:0.363985185864039
# Davies Bouldin Puanı:1.200442493980428

# %%
fig = plt.figure(figsize=(12, 7), dpi=80, facecolor='w', edgecolor='k')
ax = plt.axes(projection="3d")
ax.scatter3D(pca.T[0],pca.T[1],pca.T[2],c=hcp,cmap='Spectral')

xLabel = ax.set_xlabel('X')
yLabel = ax.set_ylabel('Y')
zLabel = ax.set_zlabel('Z')

# %%
from sklearn.mixture import GaussianMixture

# %%
models = [GaussianMixture(n,covariance_type='tied', random_state=123).fit(df1) for n in range(2,15)]
plt.plot(range(2,15), [m.bic(df1) for m in models], label='BIC')
plt.plot(range(2,15), [m.aic(df1) for m in models], label='AIC')
plt.legend()
plt.xlabel('n_bileşenler')
plt.show()

# %%
parameters=['full','tied','diag','spherical']
n_clusters=np.arange(1,21)
results_=pd.DataFrame(columns=['Kovaryans Türü','Küme Sayısı','Siluet Puanı','Davies Bouldin Puanı'])
for i in parameters:
    for j in n_clusters:
        gmm_cluster=GaussianMixture(n_components=j,covariance_type=i,random_state=123)
        clusters=gmm_cluster.fit_predict(df1)
        if len(np.unique(clusters))>=2:
            results_=results_.append({"Kovaryans Türü":i,'Küme Sayısı':j,"Siluet Puanı":metrics.silhouette_score(df1,clusters),
                                    'Davies Bouldin Puanı':metrics.davies_bouldin_score(df1,clusters)}
                                   ,ignore_index=True)
# Out:
# C:\Users\cemre\AppData\Local\Temp\ipykernel_18344\3891013490.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_=results_.append({"Kovaryans Türü":i,'Küme Sayısı':j,"Siluet Puanı":metrics.silhouette_score(df1,clusters),
# C:\Users\cemre\AppData\Local\Temp\ipykernel_18344\3891013490.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_=results_.append({"Kovaryans Türü":i,'Küme Sayısı':j,"Siluet Puanı":metrics.silhouette_score(df1,clusters),
# C:\Users\cemre\AppData\Local\Temp\ipykernel_18344\3891013490.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_=results_.append({"Kovaryans Türü":i,'Küme Sayısı':j,"Siluet Puanı":metrics.silhouette_score(df1,clusters),
# ...

# %%
display(results_.sort_values(by=["Siluet Puanı"], ascending=False)[:5])
# Out:
#    Kovaryans Türü Küme Sayısı  Siluet Puanı  Davies Bouldin Puanı
# 58      spherical           3      0.344665              0.903616
# 1            full           3      0.344665              0.903616
# 39           diag           3      0.339532              0.924758
# 38           diag           2      0.330671              1.229835
# 20           tied           3      0.322244              0.953654

# %%
gmm_cluster=GaussianMixture(n_components=3,covariance_type="spherical",random_state=123)
gmm_cluster.fit(df1)
gmm_labels = gmm_cluster.predict(df1)

# %%
fig = plt.figure(figsize=(12, 7), dpi=80, facecolor='w', edgecolor='k')
ax = plt.axes(projection="3d")
ax.scatter3D(pca.T[0],pca.T[1],pca.T[2],c=gmm_labels,cmap='Spectral')

xLabel = ax.set_xlabel('X')
yLabel = ax.set_ylabel('Y')
zLabel = ax.set_zlabel('Z')
